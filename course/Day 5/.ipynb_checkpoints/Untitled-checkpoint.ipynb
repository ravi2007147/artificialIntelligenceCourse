# %%
import matplotlib.pyplot as pt

# %%
x=[3,4,7,23,45]
y=[20,40,50,100,50]
# %matplotlib inline

# %%
pt.xlabel("x")
pt.ylabel("y")
pt.title("xy")
pt.plot(x,y,color="green",marker=".",linestyle="-")
# pt.show()
